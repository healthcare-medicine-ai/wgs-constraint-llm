# %% [markdown]
# ## Setup

# %%
# !pip install numpy
# !pip install pandas
# !pip install statsmodels

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import seaborn as sns
import statsmodels.api as sm
import gzip
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
# Specify project directories in Sherlock
data_path = '/oak/stanford/groups/mrivas/projects/wgs-constraint-llm/data/'
results_path = '/oak/stanford/groups/mrivas/projects/wgs-constraint-llm/osthoag/wgs-constraint-llm/results/'
all_results_path = '/oak/stanford/groups/mrivas/projects/wgs-constraint-llm/osthoag/wgs-constraint-llm/all results/'

# Specify the file paths
coverage_file_path = data_path + 'gnomad.exomes.v4.0.coverage.summary.tsv.bgz'

# %% [markdown]
# ## Load data

# %%
# Define model name (and absolute path)
model_name = results_path + 'HMM_rgc_0.9_over20_chr2'

# aou_predictions_df = pd.read_csv(results_path + 'HMM_rgc_0.9_over20_chr2' + '_predictions_aou_wes.tsv.gz', compression='gzip', sep='\t')
aou_predictions_df = pd.read_csv(all_results_path + 'HMM_rgc_0.9_over20_chr2' + '_predictions_aou_wes.tsv.gz', compression='gzip', sep='\t')
rgc_predictions_df = pd.read_csv(results_path + 'HMM_rgc_0.9_over20_chr2' + '_predictions_rgc_wes.tsv.gz', compression='gzip', sep='\t')

# Merge the DataFrames on the columns 'chr' and 'pos'
merged_df = pd.merge(aou_predictions_df, rgc_predictions_df, on=['chr', 'pos'], suffixes=('_aou', '_rgc'))

merged_df = merged_df.drop(columns=['prob_1_aou', 'prob_1_rgc'])

# Save results for future analysis
merged_df.to_csv(model_name + '_joint_predictions_aou_rgc_wes.tsv.gz', index=False, compression='gzip', sep='\t')

merged_df.head()
# Out:
#     chr     pos    prob_0_aou  observation_aou    prob_0_rgc  observation_rgc
# 0  chr1  925922  1.819720e-35              1.0  9.218631e-34              0.0
# 1  chr1  925923  9.853427e-03              1.0  2.515628e-03              1.0
# 2  chr1  925924  1.367878e-01              0.0  2.518103e-03              0.0
# 3  chr1  925925  1.043025e-02              0.0  4.543584e-05              1.0
# 4  chr1  925926  3.126786e-03              1.0  2.596411e-03              1.0

# %% [markdown]
# ## Compare predictions for AoU data and RGC data for WES (excluding chr2)

# %% [markdown]
# ### Perform $\chi^2$ analysis for joint distribution

# %%
# Define model name (and absolute path)
model_name = results_path + 'HMM_rgc_0.9_over20_chr2'

merged_df = pd.read_csv(model_name + '_joint_predictions_aou_rgc_wes.tsv.gz', compression='gzip', sep='\t')

# Filter out chromosome 2
merged_df = merged_df[merged_df['chr'] != 'chr2']

# Define the bins
bins = np.arange(0, 1.1, .1)

# Bucket the DataFrame to obtain marginal distributions
merged_df['prob_0_aou_bin'] = pd.cut(merged_df['prob_0_aou'], bins=bins, precision=2)
merged_df['prob_0_rgc_bin'] = pd.cut(merged_df['prob_0_rgc'], bins=bins, precision=2)

# Calculate marginal distributions
marginal_aou = merged_df['prob_0_aou_bin'].value_counts(normalize=True).sort_index()
marginal_rgc = merged_df['prob_0_rgc_bin'].value_counts(normalize=True).sort_index()

# Calculate expected joint distribution assuming independence
# expected_joint = np.outer(marginal_aou, marginal_rgc)
expected_joint = np.outer(marginal_aou, marginal_rgc) * len(merged_df)

# Calculate actual joint distribution
actual_joint = merged_df[['prob_0_aou_bin', 'prob_0_rgc_bin']].value_counts(normalize=False).sort_index()
actual_joint = np.array([[actual_joint[(aou_bin, rgc_bin)]
                          if (aou_bin, rgc_bin) in actual_joint else 0
                          for rgc_bin in marginal_rgc.index]
                         for aou_bin in marginal_aou.index])

# Identify bins with no observed data
no_data_mask = (actual_joint == 0)

# Percent difference
percent_diff = (actual_joint - expected_joint) / expected_joint
percent_diff[no_data_mask] = np.nan

# Chi-squared statistic
chi_sqr = (expected_joint - actual_joint) ** 2 / expected_joint
chi_sqr[no_data_mask] = np.nan

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 12))

# Plot expected joint distribution with log scale
sns.heatmap(expected_joint, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[0, 0], norm=LogNorm())
axs[0, 0].set_xlabel('RGC Constraint Probability')
axs[0, 0].set_ylabel('AoU Constraint Probability')
axs[0, 0].set_title('Expected Joint Distribution')
axs[0, 0].invert_yaxis()

# Plot actual joint distribution with log scale
sns.heatmap(actual_joint, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[0, 1], norm=LogNorm())
axs[0, 1].set_xlabel('RGC Constraint Probability')
axs[0, 1].set_ylabel('AoU Constraint Probability')
axs[0, 1].set_title('Actual Joint Distribution')
axs[0, 1].invert_yaxis()

# Plot percent difference
sns.heatmap(percent_diff, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[1, 0])
axs[1, 0].set_xlabel('RGC Constraint Probability')
axs[1, 0].set_ylabel('AoU Constraint Probability')
axs[1, 0].set_title('Percent Difference of Observed vs Expected Joint Distribution')
axs[1, 0].invert_yaxis()

# Plot chi-squared statistic
sns.heatmap(chi_sqr, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[1, 1])
axs[1, 1].set_xlabel('RGC Constraint Probability')
axs[1, 1].set_ylabel('AoU Constraint Probability')
axs[1, 1].set_title('Chi-Squared Statistic for Observed vs Expected Joint Distribution')
axs[1, 1].invert_yaxis()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
xticklabels = [f'{i:.1f}' for i in np.arange(0, 1.1, 0.1)]
yticklabels = [f'{i:.1f}' for i in np.arange(0, 1.1, 0.1)]

fig, ax1 = plt.subplots(1, figsize=(7, 6))

# Plot actual joint distribution with log scale
ax1 = sns.heatmap(actual_joint, cmap='Blues', annot=False, fmt=".3f", cbar=True, norm=LogNorm(), ax=ax1)
ax1.set_title('Observed Joint Distribution', fontsize=14)
ax1.set_xlabel('RGC Constraint Probability', fontsize=12)
ax1.set_ylabel('AoU Constraint Probability', fontsize=12)
ax1.invert_yaxis()
ax1.set_xticks(range(11))
ax1.set_xticklabels(xticklabels)
ax1.set_yticks(range(11))
ax1.set_yticklabels(yticklabels)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.savefig(results_path + "Figure 2a: observed joint distribution of RGC vs AoU WES constraint predictions")
plt.show()

fig, ax2 = plt.subplots(1, figsize=(7, 6))

# Plot chi-squared statistic
ax2 = sns.heatmap(chi_sqr, cmap='Blues', annot=False, fmt=".3f", cbar=True, ax=ax2)
ax2.set_title('$\chi^2$ for Observed vs Expected Joint Distribution', y=1, x=0.55, fontsize=14)
ax2.set_xlabel('RGC Constraint Probability', fontsize=12)
ax2.set_ylabel('AoU Constraint Probability', fontsize=12)
ax2.invert_yaxis()
ax2.set_xticks(range(11))
ax2.set_xticklabels(xticklabels)
ax2.set_yticks(range(11))
ax2.set_yticklabels(yticklabels)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.savefig(results_path + "Figure 2b: chi-square statistics of RGC vs AoU WES constraint predictions")
plt.show()

# %%
# Step 1: Compute Chi-Square Statistics
chi_square_dict = {}

for chrom in merged_df["chr"].unique():
    df_chr = merged_df[merged_df["chr"] == chrom].copy()

    # Calculate marginal distributions
    marginal_aou = df_chr['prob_0_aou_bin'].value_counts(normalize=True).sort_index()
    marginal_rgc = df_chr['prob_0_rgc_bin'].value_counts(normalize=True).sort_index()

    # Calculate expected joint distribution assuming independence
    # expected_joint = np.outer(marginal_aou, marginal_rgc)
    expected_joint = np.outer(marginal_aou, marginal_rgc) * len(df_chr)

    # Calculate actual joint distribution
    actual_joint = df_chr[['prob_0_aou_bin', 'prob_0_rgc_bin']].value_counts(normalize=False).sort_index()
    actual_joint = np.array([[actual_joint[(aou_bin, rgc_bin)]
                              if (aou_bin, rgc_bin) in actual_joint else 0
                              for rgc_bin in marginal_rgc.index]
                             for aou_bin in marginal_aou.index])

    # Calculate chi-squared statistic
    chi_sqr = (expected_joint - actual_joint) ** 2 / expected_joint
    chi_sqr = np.nan_to_num(chi_sqr)
        
    # Store in dictionary
    chi_square_dict[chrom] = chi_sqr
    

bottom_left_chi2_values = [chi2[0][0] for chi2 in chi_square_dict.values()]
top_right_chi2_values = [chi2[-1][-1] for chi2 in chi_square_dict.values()]
top_left_chi2_values = [chi2[0][-1] for chi2 in chi_square_dict.values()]
bottom_right_chi2_values = [chi2[-1][0] for chi2 in chi_square_dict.values()]
print(f"Chi-square range of low-low constraint regions: ({min(bottom_left_chi2_values)}, {max(bottom_left_chi2_values)})")
print(f"Chi-square range of high-high constraint regions: ({min(top_right_chi2_values)}, {max(top_right_chi2_values)})")
print(f"Chi-square range of low-high constraint regions: ({min(top_left_chi2_values)}, {max(top_left_chi2_values)})")
print(f"Chi-square range of high-low constraint regions: ({min(bottom_right_chi2_values)}, {max(bottom_right_chi2_values)})")

# Plot histogram for (0.9, 1.0]
plt.figure(figsize=(8, 6))
plt.hist(top_right_chi2_values, bins=30, alpha=0.5, label="top right", color="blue")
plt.hist(bottom_left_chi2_values, bins=30, alpha=0.5, label="bottom left", color="purple")
plt.hist(top_left_chi2_values, bins=30, alpha=0.5, label="top left", color="red")
plt.hist(bottom_right_chi2_values, bins=30, alpha=0.5, label="bottom right", color="orange")
plt.xlabel("Chi-Square Statistic")
plt.ylabel("Frequency")
plt.title("Histogram of Chi-Square Statistics in different quadrants")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Chi-square range of low-low constraint regions: (6220.027846356691, 74891.48221166528)
# Chi-square range of high-high constraint regions: (12925.078561905308, 141665.14364860553)
# Chi-square range of low-high constraint regions: (2973.4750066265583, 37241.17841102886)
# Chi-square range of high-low constraint regions: (3268.387744419399, 37987.60280422383)

# %% [markdown]
# ### Repeat $\chi^2$ analysis for joint invariant sites

# %%
# Define model name (and absolute path)
model_name = results_path + 'HMM_rgc_0.9_over20_chr2'

merged_df = pd.read_csv(model_name + '_joint_predictions_aou_rgc_wes.tsv.gz', compression='gzip', sep='\t')

# Filter out chromosome 2
merged_df = merged_df[merged_df['chr'] != 'chr2']

# Exclude sites invariant in both datasets
merged_df = merged_df[((merged_df['observation_aou'] == 0) & (merged_df['observation_rgc'] == 0))]

# Define the bins
bins = np.arange(0, 1.1, .1)

# Bucket the DataFrame to obtain marginal distributions
merged_df['prob_0_aou_bin'] = pd.cut(merged_df['prob_0_aou'], bins=bins, precision=2)
merged_df['prob_0_rgc_bin'] = pd.cut(merged_df['prob_0_rgc'], bins=bins, precision=2)

# Calculate marginal distributions
marginal_aou = merged_df['prob_0_aou_bin'].value_counts(normalize=True).sort_index()
marginal_rgc = merged_df['prob_0_rgc_bin'].value_counts(normalize=True).sort_index()

# Calculate expected joint distribution assuming independence
# expected_joint = np.outer(marginal_aou, marginal_rgc)
expected_joint = np.outer(marginal_aou, marginal_rgc) * len(merged_df)

# Calculate actual joint distribution
actual_joint = merged_df[['prob_0_aou_bin', 'prob_0_rgc_bin']].value_counts(normalize=False).sort_index()
actual_joint = np.array([[actual_joint[(aou_bin, rgc_bin)]
                          if (aou_bin, rgc_bin) in actual_joint else 0
                          for rgc_bin in marginal_rgc.index]
                         for aou_bin in marginal_aou.index])

# Calculate percent difference
percent_diff = (actual_joint - expected_joint) / expected_joint
percent_diff = np.nan_to_num(percent_diff)

# Calculate chi-squared statistic
chi_sqr = (expected_joint - actual_joint) ** 2 / expected_joint
chi_sqr = np.nan_to_num(chi_sqr)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 12))

# Plot expected joint distribution with log scale
sns.heatmap(expected_joint, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[0, 0], norm=LogNorm())
axs[0, 0].set_xlabel('RGC Constraint Probability')
axs[0, 0].set_ylabel('AoU Constraint Probability')
axs[0, 0].set_title('Expected Joint Distribution')
axs[0, 0].invert_yaxis()

# Plot actual joint distribution with log scale
sns.heatmap(actual_joint, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[0, 1], norm=LogNorm())
axs[0, 1].set_xlabel('RGC Constraint Probability')
axs[0, 1].set_ylabel('AoU Constraint Probability')
axs[0, 1].set_title('Actual Joint Distribution')
axs[0, 1].invert_yaxis()

# Plot percent difference
sns.heatmap(percent_diff, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[1, 0])
axs[1, 0].set_xlabel('RGC Constraint Probability')
axs[1, 0].set_ylabel('AoU Constraint Probability')
axs[1, 0].set_title('Percent Difference of Observed vs Expected Joint Distribution')
axs[1, 0].invert_yaxis()

# Plot chi-squared statistic
sns.heatmap(chi_sqr, cmap='Blues', annot=False, fmt=".3f", cbar=True, xticklabels=marginal_rgc.index, yticklabels=marginal_aou.index, ax=axs[1, 1])
axs[1, 1].set_xlabel('RGC Constraint Probability')
axs[1, 1].set_ylabel('AoU Constraint Probability')
axs[1, 1].set_title('Chi-Squared Statistic for Observed vs Expected Joint Distribution')
axs[1, 1].invert_yaxis()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd

# Load and preprocess
model_name = results_path + 'HMM_rgc_0.9_over20_chr2'
merged_df = pd.read_csv(model_name + '_joint_predictions_aou_rgc_wes.tsv.gz', compression='gzip', sep='\t')
merged_df = merged_df[merged_df['chr'] != 'chr2']
merged_df['variation_pattern'] = (
    merged_df['observation_rgc'].astype(int).astype(str) + 
    merged_df['observation_aou'].astype(int).astype(str)
)

bins = np.arange(0, 1.1, 0.1)

# Utility: Compute actual + expected joint matrix
def compute_joint_matrix(df, x_col, y_col, bins):
    df = df.copy()
    df['x_bin'] = pd.cut(df[x_col], bins=bins)
    df['y_bin'] = pd.cut(df[y_col], bins=bins)
    marginal_x = df['x_bin'].value_counts(normalize=True).sort_index()
    marginal_y = df['y_bin'].value_counts(normalize=True).sort_index()
    expected_joint = np.outer(marginal_x, marginal_y) * len(df)
    actual_joint = df[['x_bin', 'y_bin']].value_counts().sort_index()
    actual_matrix = np.array([
        [actual_joint.get((x_bin, y_bin), 0) for y_bin in marginal_y.index]
        for x_bin in marginal_x.index
    ])
    return actual_matrix, expected_joint, marginal_x.index, marginal_y.index

# Utility: Compute chi-squared
def compute_chisq_matrix(actual, expected):
    with np.errstate(divide='ignore', invalid='ignore'):
        chisq = (actual - expected) ** 2 / expected
        chisq = np.nan_to_num(chisq)
    return chisq

# Extract '00' and 'non-00' data
df_00 = merged_df[merged_df['variation_pattern'] == '00']
df_non00 = merged_df[merged_df['variation_pattern'].isin(['01', '10', '11'])]

# Compute matrices
actual_00, expected_00, xticks, yticks = compute_joint_matrix(df_00, 'prob_0_rgc', 'prob_0_aou', bins)
chisq_00 = compute_chisq_matrix(actual_00, expected_00)

actual_non00, expected_non00, _, _ = compute_joint_matrix(df_non00, 'prob_0_rgc', 'prob_0_aou', bins)
chisq_non00 = compute_chisq_matrix(actual_non00, expected_non00)

# Plotting
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Top row: '00'
sns.heatmap(actual_00, ax=axs[0, 0], cmap='Blues', norm=LogNorm(), xticklabels=xticks, yticklabels=yticks, cbar=True)
axs[0, 0].invert_yaxis()
axs[0, 0].set_title("Actual Joint (Pattern '00')")
axs[0, 0].set_xlabel("RGC Constraint Probability")
axs[0, 0].set_ylabel("AoU Constraint Probability")

sns.heatmap(chisq_00, ax=axs[0, 1], cmap='Blues', xticklabels=xticks, yticklabels=yticks, cbar=True)
axs[0, 1].invert_yaxis()
axs[0, 1].set_title("Chi-squared (Pattern '00')")
axs[0, 1].set_xlabel("RGC Constraint Probability")
axs[0, 1].set_ylabel("AoU Constraint Probability")

# Bottom row: non-'00'
sns.heatmap(actual_non00, ax=axs[1, 0], cmap='Blues', norm=LogNorm(), xticklabels=xticks, yticklabels=yticks, cbar=True)
axs[1, 0].invert_yaxis()
axs[1, 0].set_title("Actual Joint (Patterns '01', '10', '11')")
axs[1, 0].set_xlabel("RGC Constraint Probability")
axs[1, 0].set_ylabel("AoU Constraint Probability")

sns.heatmap(chisq_non00, ax=axs[1, 1], cmap='Blues', xticklabels=xticks, yticklabels=yticks, cbar=True)
axs[1, 1].invert_yaxis()
axs[1, 1].set_title("Chi-squared (Patterns '01', '10', '11')")
axs[1, 1].set_xlabel("RGC Constraint Probability")
axs[1, 1].set_ylabel("AoU Constraint Probability")

plt.tight_layout()
plt.show()

# %%
from scipy.stats import pearsonr, spearmanr

# Create pattern column again in case it's missing
merged_df['variation_pattern'] = (
    merged_df['observation_rgc'].astype(int).astype(str) + 
    merged_df['observation_aou'].astype(int).astype(str)
)

# Define groups
group_00 = merged_df[merged_df['variation_pattern'] == '00']
group_non00 = merged_df[merged_df['variation_pattern'] != '00']

# Compute correlation statistics
def report_corr(df, label):
    pearson = pearsonr(df['prob_0_rgc'], df['prob_0_aou'])
    spearman = spearmanr(df['prob_0_rgc'], df['prob_0_aou'])
    print(f"\n{label}")
    print(f"  Pearson r = {pearson[0]:.3f} (p = {pearson[1]:.2e})")
    print(f"  Spearman ρ = {spearman.correlation:.3f} (p = {spearman.pvalue:.2e})")

report_corr(group_00, "Jointly Invariant Positions (Pattern '00')")
report_corr(group_non00, "Other Positions (Patterns '01', '10', '11')")
# Out:
# Jointly Invariant Positions (Pattern '00')
#   Pearson r = 0.424 (p = 0.00e+00)
#   Spearman ρ = 0.454 (p = 0.00e+00)
#
# Other Positions (Patterns '01', '10', '11')
#   Pearson r = -0.112 (p = 0.00e+00)
#   Spearman ρ = 0.262 (p = 0.00e+00)

# %% [markdown]
# ### Additional validation

# %%
# Load and preprocess
model_name = results_path + 'HMM_rgc_0.9_over20_chr2'
merged_df = pd.read_csv(model_name + '_joint_predictions_aou_rgc_wes.tsv.gz', compression='gzip', sep='\t')
merged_df = merged_df[merged_df['chr'] != 'chr2']

# Step 1: Filter to invariant sites in RGC
invariant_rgc = merged_df[merged_df['observation_rgc'] == 0]

# Step 2: Keep only high and low predicted constraint
high_constraint = invariant_rgc[invariant_rgc['prob_0_rgc'] > 0.8]
low_constraint = invariant_rgc[invariant_rgc['prob_0_rgc'] < 0.2]

# Step 3: Build 2x2 contingency table
# Rows: HMM predicted constraint (high vs low)
# Cols: AoU variant observed (yes or no)
high_variant = high_constraint['observation_aou'].sum()
high_total = len(high_constraint)

low_variant = low_constraint['observation_aou'].sum()
low_total = len(low_constraint)

# Construct contingency table
from scipy.stats import chi2_contingency

contingency_table = pd.DataFrame({
    'AoU_variant=1': [high_variant, low_variant],
    'AoU_variant=0': [high_total - high_variant, low_total - low_variant]
}, index=['HMM_high_constraint', 'HMM_low_constraint'])

# Chi-square test
chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)

contingency_table, p_val
# Out:
# (                     AoU_variant=1  AoU_variant=0
#  HMM_high_constraint       248028.0      2095342.0
#  HMM_low_constraint        952127.0      6794720.0,
#  0.0)

# %% [markdown]
# ### Perform correspondence analysis for joint distribution

# %%
import numpy as np
from scipy.sparse.linalg import svds
from sklearn.preprocessing import StandardScaler

# Calculate row and column totals
row_totals = np.sum(actual_joint, axis=1)
col_totals = np.sum(actual_joint, axis=0)

# Add a small constant to avoid division by zero
row_totals = row_totals + 1e-10
col_totals = col_totals + 1e-10

# Calculate row and column profiles
row_profiles = actual_joint / row_totals[:, None]
col_profiles = actual_joint / col_totals[None, :]

# Replace inf or NaN values with a finite number
row_profiles = np.nan_to_num(row_profiles, nan=0.0, posinf=0.0, neginf=0.0)
col_profiles = np.nan_to_num(col_profiles, nan=0.0, posinf=0.0, neginf=0.0)

# Calculate chi-square distance matrix
D_r = np.diag(1.0 / np.sqrt(row_totals))
D_c = np.diag(1.0 / np.sqrt(col_totals))
S = D_r @ (row_profiles - col_profiles) @ D_c

# Perform singular value decomposition
U, s, Vt = svds(S, k=min(S.shape) - 1)

# Calculate row and column coordinates
F_r = D_r @ U @ np.diag(np.sqrt(s))
F_c = D_c @ Vt.T @ np.diag(np.sqrt(s))

# Standardize the coordinates
scaler = StandardScaler()
F_r = scaler.fit_transform(F_r)
F_c = scaler.transform(F_c)

# %%
import matplotlib.pyplot as plt

# Create a new figure
plt.figure(figsize=(10, 10))

# Plot row points and labels
plt.scatter(F_r[:, 0], F_r[:, 1], color='blue', label='AoU')
for i, label in enumerate(marginal_aou.index):
    if i==5:
        plt.text(F_r[i, 0]-0.25, F_r[i, 1]-0.1, label, color='blue')
    elif i==2:
        plt.text(F_r[i, 0], F_r[i, 1]+0.025, label, color='blue')
    elif i==9:
        plt.text(F_r[i, 0], F_r[i, 1]-0.05, label, color='blue')
    else:
        plt.text(F_r[i, 0], F_r[i, 1], label, color='blue')

# Plot column points and labels
plt.scatter(F_c[:, 0], F_c[:, 1], color='red', label='RGC')
for i, label in enumerate(marginal_rgc.index):
    plt.text(F_c[i, 0]-0.75, F_c[i, 1]-0.075, label, color='red')

# Add a legend
plt.legend()

# Add title
plt.title("BiPlot of AoU and RGC joint distribution bins")

# Show the plot
plt.show()

# %% [markdown]
# ### Evaluate correlation via GLM

# %%
# Assuming merged_df is your DataFrame with columns 'prob_0_aou' and 'prob_0_rgc'
ax = sns.jointplot(
    data=merged_df[merged_df['chr'] != 'chr2'],
    x='prob_0_aou',
    y='prob_0_rgc',
    kind='hex',
    cmap='Blues',  # Change the colormap to Blues
    norm=LogNorm(),  # Use logarithmic scale
    marginal_kws=dict(bins=10),
#     histplot_kws=dict(func='log'),  # Set log scale for marginal histogram
#     kdeplot_kws=dict(func='log'),  # Set log scale for marginal KDE
    gridsize=9,  # Set grid size to 9
)

# Add labels and title
ax.set_axis_labels('AoU Constraint Probability', 'RGC Constraint Probability', fontsize=11)
ax.fig.suptitle(r'Joint Distribution of RGC and AoU Constraint Probabilities for WES', y=1.05, x=0.5, fontsize=12)  # Adjust title position and make it bold

# Add colorbar
cbar_ax = ax.fig.add_axes([1, 0.1, 0.03, 0.6])  # Adjust the position as needed
cb = plt.colorbar(cax=cbar_ax)

# Set colorbar label
cb.set_label('Log-Scaled Count')

# Show the plot
plt.savefig(results_path + "Figure 2: RGC vs AoU WES constraint predictions")
plt.show()

# %%
X = merged_df['prob_0_aou']
X = sm.add_constant(X)
y = merged_df['prob_0_rgc']

# Fit the logistic regression model
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             prob_0_rgc   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                 4.818e+06
# Date:                Tue, 11 Mar 2025   Prob (F-statistic):               0.00
# Time:                        16:41:29   Log-Likelihood:            -4.4231e+06
# No. Observations:            26736781   AIC:                         8.846e+06
# Df Residuals:                26736779   BIC:                         8.846e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0758   7.52e-05   1007.712      0.000       0.076       0.076
# prob_0_aou     0.3048      0.000   2195.097      0.000       0.305       0.305
# ==============================================================================
# Omnibus:                  4175915.113   Durbin-Watson:                   0.496
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6408958.234
# Skew:                           1.158   Prob(JB):                         0.00
# Kurtosis:                       3.625   Cond. No.                         2.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
